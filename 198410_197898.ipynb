# %% [markdown]
# # Techniki Programowania - Projekt 3
# * Kamil Jaworski 198410
# * Michał Czechowicz 197898
# ## Generowanie sygnałów:
# Biblioteka daje możliwość wygenerowania sygnału sinus,cosinus, prostokątnego oraz piłokształtnego.
# Dla sygnału można ustawić takie parametry jak: Amplituda, Częstotliwość, oraz czas trwania

# %%
import pybind11module
frequency = 10.0
amplitude = 2.0
duration = 2
pybind11module.INIT()
pybind11module.Cosinus(frequency, amplitude, duration)

# %%
import pybind11module
frequency = 10.0
amplitude = 2.0
duration = 2
pybind11module.INIT()
pybind11module.Sinus(frequency, amplitude, duration)

# %%
import pybind11module
frequency = 10.0
amplitude = 2.0
duration = 2
pybind11module.INIT()
pybind11module.SquareWave(frequency, amplitude, duration)

# %%
import pybind11module
frequency = 10.0
amplitude = 2.0
duration = 2
pybind11module.INIT()
pybind11module.Sawtooth(frequency, amplitude, duration)

# %% [markdown]
# ![image.png](attachment:fea1c7e0-4dd5-49c9-a745-10f5a2f83fa0.png)
# ![image.png](attachment:5da90988-4608-4a12-9568-587ac173af06.png)
# ![image.png](attachment:e78e8964-0ee5-431d-a2d4-1bfe51fae57c.png)
# ![image.png](attachment:080c94fc-2e2e-40cb-ba10-71a4c29f892e.png)

# %% [markdown]
# ## Funkcja Generowania zaszumionego sygnału
# Generuje sygnał sinus o podanych  parametrach z dodatkiem szumu

# %%
import pybind11module
frequency = 20.0
amplitude = 2.0
duration = 2
pybind11module.INIT()
pybind11module.generateNoise(frequency, amplitude, duration)

# %% [markdown]
# ![image.png](attachment:72b35a54-42ff-4122-b35b-1e6a730ab919.png)

# %% [markdown]
# ## Funkcja odczytywania pliku audio
# Wystarczy podać jako argument funkcji plik.wav, którego 500 pierwszych sampli zostanie następnie wyświetlonych

# %%
import pybind11module
import matplotlib.pyplot as plt
frequency = 20.0
amplitude = 2.0
duration = 2
pybind11module.INIT()
plt.savefig('Audio.png')
pybind11module.show_AudioFile("C:\\Users\\Lenovo\\Desktop\\studying\\Techniki Programowania\\Project_signals\\Project_3\\Audio\\test-tones\\50hz.wav")

# %% [markdown]
# ![image.png](attachment:12844aa4-e3bb-4d02-8d92-58ad80365034.png)
